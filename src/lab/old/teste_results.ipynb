# %%
import pandas as pd
import numpy as np

# %%
content = """
[
  {
    "id": 1,
    "created_at": "2024-03-29T10:00:00",
    "subject_matter_1": "Mathematics",
    "subject_matter_2": "Algebra",
    "topic_description": "Solving linear equations",
    "level": "Beginner",
    "question": "What is the solution to 2x + 3 = 11?",
    "answer": "x = 4",
    "explanation": "Subtract 3 from both sides, then divide by 2 to isolate x.",
    "accepted": true,
    "show_again": true,
    "correct_answer": true
  },
  {
    "id": 2,
    "created_at": "2024-03-29T10:05:00",
    "subject_matter_1": "Biology",
    "subject_matter_2": "Anatomy",
    "topic_description": "Human Digestive System",
    "level": "Intermediate",
    "question": "Which enzyme helps in digesting proteins?",
    "answer": "Trypsin",
    "explanation": "Trypsin is produced in the pancreas and helps in breaking down proteins in the small intestine.",
    "accepted": true,
    "show_again": true,
    "correct_answer": true
  },
  {
    "id": 3,
    "created_at": "2024-03-29T10:10:00",
    "subject_matter_1": "History",
    "subject_matter_2": "World War II",
    "topic_description": "Battle of Stalingrad",
    "level": "Advanced",
    "question": "What year did the Battle of Stalingrad begin?",
    "answer": "1942",
    "explanation": "The Battle of Stalingrad began in the summer of 1942 and lasted until early 1943.",
    "accepted": true,
    "show_again": true,
    "correct_answer": true
  },
  {
    "id": 4,
    "created_at": "2024-03-29T10:15:00",
    "subject_matter_1": "Computer Science",
    "subject_matter_2": "Programming",
    "topic_description": "Object-Oriented Programming",
    "level": "Beginner",
    "question": "What is inheritance in object-oriented programming?",
    "answer": "It allows a class to inherit properties and behavior from another class.",
    "explanation": "Inheritance promotes code reusability and establishes a relationship between classes.",
    "accepted": true,
    "show_again": true,
    "correct_answer": true
  },
  {
    "id": 5,
    "created_at": "2024-03-29T10:20:00",
    "subject_matter_1": "Chemistry",
    "subject_matter_2": "Organic Chemistry",
    "topic_description": "Alkanes",
    "level": "Intermediate",
    "question": "What is the general formula for alkanes?",
    "answer": "CnH2n+2",
    "explanation": "Alkanes are saturated hydrocarbons consisting of carbon and hydrogen atoms with single bonds.",
    "accepted": true,
    "show_again": true,
    "correct_answer": true
  },
  {
    "id": 6,
    "created_at": "2024-03-29T10:25:00",
    "subject_matter_1": "Literature",
    "subject_matter_2": "English Poetry",
    "topic_description": "Shakespearean Sonnets",
    "level": "Advanced",
    "question": "Which Shakespearean sonnet begins with the line 'Shall I compare thee to a summer's day?'",
    "answer": "Sonnet 18",
    "explanation": "Sonnet 18 is one of the most famous sonnets by William Shakespeare.",
    "accepted": true,
    "show_again": true,
    "correct_answer": true
  },
  {
    "id": 7,
    "created_at": "2024-03-29T10:30:00",
    "subject_matter_1": "Physics",
    "subject_matter_2": "Mechanics",
    "topic_description": "Newton's Laws of Motion",
    "level": "Beginner",
    "question": "What is Newton's first law of motion?",
    "answer": "An object at rest will remain at rest, and an object in motion will remain in motion unless acted upon by an external force.",
    "explanation": "This law is also known as the law of inertia.",
    "accepted": true,
    "show_again": true,
    "correct_answer": true
  },
  {
    "id": 8,
    "created_at": "2024-03-29T10:35:00",
    "subject_matter_1": "Geography",
    "subject_matter_2": "Physical Geography",
    "topic_description": "Plate Tectonics",
    "level": "Intermediate",
    "question": "What type of boundary is the San Andreas Fault an example of?",
    "answer": "Transform boundary",
    "explanation": "The San Andreas Fault is a transform boundary between the Pacific Plate and the North American Plate.",
    "accepted": true,
    "show_again": true,
    "correct_answer": true
  },
  {
    "id": 9,
    "created_at": "2024-03-29T10:40:00",
    "subject_matter_1": "Economics",
    "subject_matter_2": "Microeconomics",
    "topic_description": "Supply and Demand",
    "level": "Advanced",
    "question": "What happens to equilibrium price and quantity when demand increases and supply decreases?",
    "answer": "Equilibrium price increases, and equilibrium quantity decreases.",
    "explanation": "This leads to a shortage in the market.",
    "accepted": true,
    "show_again": true,
    "correct_answer": true
  },
  {
    "id": 10,
    "created_at": "2024-03-29T10:45:00",
    "subject_matter_1": "Psychology",
    "subject_matter_2": "Behavioral Psychology",
    "topic_description": "Classical Conditioning",
    "level": "Beginner",
    "question": "Who is known for the classical conditioning experiment involving dogs?",
    "answer": "Ivan Pavlov",
    "explanation": "Pavlov's experiment demonstrated associative learning through conditioned responses.",
    "accepted": true,
    "show_again": true,
    "correct_answer": true
  },
  {
    "id": 11,
    "created_at": "2024-03-29T10:50:00",
    "subject_matter_1": "Art",
    "subject_matter_2": "Renaissance Art",
    "topic_description": "Leonardo da Vinci",
    "level": "

"""

# %%
import  json_repair

j = json_repair.loads(content)

# %%
df = pd.DataFrame(j)
df
# Out:
#     id           created_at  subject_matter_1       subject_matter_2  \
# 0    1  2024-03-29T10:00:00       Mathematics                Algebra
# 1    2  2024-03-29T10:05:00           Biology                Anatomy
# 2    3  2024-03-29T10:10:00           History           World War II
# 3    4  2024-03-29T10:15:00  Computer Science            Programming
# 4    5  2024-03-29T10:20:00         Chemistry      Organic Chemistry
# 5    6  2024-03-29T10:25:00        Literature         English Poetry
# 6    7  2024-03-29T10:30:00           Physics              Mechanics
# 7    8  2024-03-29T10:35:00         Geography     Physical Geography
# 8    9  2024-03-29T10:40:00         Economics         Microeconomics
# 9   10  2024-03-29T10:45:00        Psychology  Behavioral Psychology
# 10  11  2024-03-29T10:50:00               Art        Renaissance Art
#
#               topic_description         level  \
# 0      Solving linear equations      Beginner
# ...

# %%
df.groupby("subject_matter_1")["correct_answer"].sum()
# Out:
# subject_matter_1
# Art                    0
# Biology             True
# Chemistry           True
# Computer Science    True
# Economics           True
# Geography           True
# History             True
# Literature          True
# Mathematics         True
# Physics             True
# Psychology          True
# Name: correct_answer, dtype: object

# %%
df = pd.read_csv("teste_results.ipynb (df) - teste_results.ipynb (df).csv")
df
# Out:
#     id           created_at  subject_matter_1       subject_matter_2  \
# 0    1  2024-03-29 10:00:00       Mathematics                Algebra
# 1    2  2024-03-29 10:05:00       Mathematics                Anatomy
# 2    3  2024-03-29 10:10:00       Mathematics           World War II
# 3    4  2024-03-29 10:15:00  Computer Science            Programming
# 4    5  2024-03-29 10:20:00  Computer Science      Organic Chemistry
# 5    6  2024-03-29 10:25:00  Computer Science         English Poetry
# 6    7  2024-03-29 10:30:00  Computer Science              Mechanics
# 7    8  2024-03-29 10:35:00        Psychology     Physical Geography
# 8    9  2024-03-29 10:40:00        Psychology         Microeconomics
# 9   10  2024-03-29 10:45:00        Psychology  Behavioral Psychology
# 10  11  2024-03-29 10:50:00        Psychology        Renaissance Art
# 11  12  2024-03-29 10:00:00       Mathematics                Algebra
# 12  13  2024-03-29 10:05:00       Mathematics                Anatomy
# ...

# %%
df.groupby(["subject_matter_1", "level"])["correct_answer"].sum().reset_index()
# Out:
#    subject_matter_1         level correct_answer
# 0  Computer Science      Advanced              1
# 1  Computer Science      Beginner              0
# 2  Computer Science  Intermediate              2
# 3       Mathematics      Advanced              2
# 4       Mathematics      Beginner              0
# 5       Mathematics  Intermediate              1
# 6        Psychology      Advanced              1
# 7        Psychology      Beginner              1
# 8        Psychology  Intermediate              1

# %%
df['correct_answer'] = df['correct_answer'].replace(True, 1)
df['correct_answer'] = df['correct_answer'].replace(False, 0)
# Out:
# /tmp/ipykernel_365899/468741938.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['correct_answer'] = df['correct_answer'].replace(False, 0)

# %%
correct_mask = df['correct_answer'] == 1
correct_df = df.loc[ correct_mask ].groupby(["subject_matter_1", "level"])['correct_answer'].sum().reset_index()
correct_df
# Out:
#    subject_matter_1         level  correct_answer
# 0  Computer Science      Advanced             1.0
# 1  Computer Science  Intermediate             2.0
# 2       Mathematics      Advanced             2.0
# 3       Mathematics  Intermediate             1.0
# 4        Psychology      Advanced             1.0
# 5        Psychology      Beginner             1.0
# 6        Psychology  Intermediate             1.0

# %%
incorrect_mask = df['correct_answer'] == 0
incorrect_df = df.loc[ incorrect_mask ].groupby(["subject_matter_1", "level"])['correct_answer'].count().reset_index()
incorrect_df = incorrect_df.rename(columns={"correct_answer": "incorrect_answer"})
incorrect_df
# Out:
#    subject_matter_1         level  incorrect_answer
# 0  Computer Science      Advanced                 1
# 1  Computer Science      Beginner                 4
# 2       Mathematics      Beginner                 2
# 3       Mathematics  Intermediate                 1
# 4        Psychology      Advanced                 1
# 5        Psychology      Beginner                 1
# 6        Psychology  Intermediate                 1

# %%
df_results = pd.merge(correct_df, incorrect_df, on=["subject_matter_1", "level"], how='outer')
df_results.fillna(0, inplace=True)
df_results["correct_answer"] = df_results["correct_answer"].astype(int)
df_results["incorrect_answer"] = df_results["incorrect_answer"].astype(int)
df_results
# Out:
#    subject_matter_1         level  correct_answer  incorrect_answer
# 0  Computer Science      Advanced               1                 1
# 1  Computer Science      Beginner               0                 4
# 2  Computer Science  Intermediate               2                 0
# 3       Mathematics      Advanced               2                 0
# 4       Mathematics      Beginner               0                 2
# 5       Mathematics  Intermediate               1                 1
# 6        Psychology      Advanced               1                 1
# 7        Psychology      Beginner               1                 1
# 8        Psychology  Intermediate               1                 1
